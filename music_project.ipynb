# %%
#import libraries
from googleapiclient.discovery import build
import requests
import pandas as pd 
import time 
import seaborn as sns

# %% [markdown]
# WORKING WITH APIs in python

# %%
api_key="AIzaSyAc0XVdGzbCjsx8ClrHetQNhOzbrTA1LsQ" 
#channel_id="UCSyGLZWpjz1hsIUvwAu9gaQ" # makhadzi
channel_ids=["UCCkS5IGDjJpGq_kZ1GrCaIA",  # Gusba BANANA
             "UCVXZ4LulZqsmFF29R3qyGPA" , #nadiavocals
             "UCkOVK-tMYtEITJkzsnm-uUg" , #sho majozi
             "UCo2BGjLFVkcpEMW7QNFPPEA" , #RAMZEEY RAMALATA
             "UC7TpYjCzu-dYasv9w7ueYFg" , #KING MONADA
             "UCdMDQN_f5XjPkGs7fVnKzWQ" , #MOTLANALO RAMMALO
             "UCDoqTVbyWomVpwILXStPxOA",  #Benny Mayengani
             "UCSyGLZWpjz1hsIUvwAu9gaQ",  # makhadzi"
             "UCF1GnbtO_EQN0RD-INPr9xg", # Mizo Phyll 
             "UCjd8RxnPXM27yi7JdTNJ8Wg" ,#Ras Canly
             "UCxajDywxM8c6ytcDaG4zSKg",  #Makheda SA
             "UC9D-KtTytb5RdNIz8CRoeDQ", #corbert mokhevuwo
             "UCqtb4ILfmu5hHzWCe3z-I3Q" #provo
             "UC7_N4T_uVxM8_QgY6llsvfA",#tygaboy mukoni
             "UC6sqUiGuIGInOQmYGKWyJ9w",  #cyria community
             "UCMD0hx3T--j41sKlgBPQ1aw", #romeo the great white
             "UCAec-MsTrEBYovka_hm50SQ", # Dj mfudisi
             "UCY190S6_4QmDP84uZ_rPicg", #Rol dee
             "UClWGgxeiYA0R_AG2o4T2eUQ",#fortunator SA
             "UCUHb32PVvNsP0KSaxFH7YBg", # razie kay
             "UC5nD6b4IuSqxNkAWa44k2CA", #rude kid
             "UCmek3pqgwHEt5h2OG5VB8LA", #khakhathi and friends
             "UCusa9C4gAGyyLh3rsXENgOg", # dalo dey
             "UC2a6McsMKXln03jY9OOE3gg", #vhudi
             "UCLDr5AHagBvAS8n4nS2VlZQ", #jack bunny
             "UCVHb0R6i0EYBHq2ql4m-bYQ", #pro heed
             "UC4jsjy_PHjUjNDI6_h8n4nA", #una rine
             "UCbDu5R2Pp43p1vh-U3mNvQw", #pross boy
             "UC1Cu7sPjP-PAO2kQMJZmapg", #GLASS VILL
             "UCaTnvqXSDfojmzgBjDtLQog", #Irene mawela
             "UCX6VHXnryBSxN8IVmJEvCKA",
             "UCVgbdGZ1WXl_x5qCn62synw", #azambia band
             "UCdJXZC60pVWjvz8s6EZcetA",#zozo
             "UC1aLicQkGXb4gWoi_Qzb5wg",#thomas chauke
             "UCzHaBer4Y60GSpSPuHACpig",#benny mayengani
             "UCiaamLz73Sani_kxmQ310DA" ,#RACHAKILL
             "UCHuFdIMcaLen0pGQBjEeorg" #metro CMG
             
             
    
]
youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# FUNCTION TO GET CHANNEL STATISTICS

# %%
def get_channel_stats(youtube,channel_ids):
     all_data=[]
     request = youtube.channels().list (
            part="snippet,contentDetails,statistics",
            id=",".join(channel_ids))
     response=request.execute()

     for i in range(len(response['items'])):
       data= dict(Channel_name=response['items'][i]['snippet']['title'],
              Subscribers=response['items'][i]['statistics']['subscriberCount'],
               Views=response['items'][i]['statistics']['viewCount'],
              Total_videos=response['items'][i]['statistics']['videoCount']
               
               )
       all_data.append(data)
     return all_data

# %%
get_channel_stats(youtube,channel_ids)
# Out:
# [{'Channel_name': 'Racha Kill',
#   'Subscribers': '3360',
#   'Views': '561979',
#   'Total_videos': '63'},
#  {'Channel_name': 'Masingi Music Production',
#   'Subscribers': '661',
#   'Views': '72673',
#   'Total_videos': '32'},
#  {'Channel_name': 'Khakhathi & Friends - Topic',
#   'Subscribers': '2570',
#   'Views': '1069046',
#   'Total_videos': '26'},
#  {'Channel_name': 'Swaka Chauke Tv',
#   'Subscribers': '2900',
#   'Views': '247763',
#   'Total_videos': '388'},
#  {'Channel_name': 'Jack Bunny',
#   'Subscribers': '1680',
#   'Views': '86709',
#   'Total_videos': '10'},
#  {'Channel_name': 'Cyria the Community - Topic',
#   'Subscribers': '226',
#   'Views': '548229',
#   'Total_videos': '17'},
#  {'Channel_name': 'NADIAVOCAL',
#   'Subscribers': '306',
#   'Views': '20667',
#   'Total_videos': '12'},
#  {'Channel_name': 'Pro Heed Agency',
#   'Subscribers': '832',
#   'Views': '59591',
#   'Total_videos': '2'},
#  {'Channel_name': 'Ras Canly',
#   'Subscribers': '4940',
# ...

# %%
channel_statistics=get_channel_stats(youtube,channel_ids)

# %%
channel_data=pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#                         Channel_name Subscribers     Views Total_videos
# 0                          Razie kay        5850    555909           44
# 1                           Una Rine        1710    115621           11
# 2                       Irene Mawela         577    102491            5
# 3        Cyria the Community - Topic         226    548229           17
# 4                     Rude Kid Venda       24000   1729387           86
# 5                          Metro CMG        3420    337398           20
# 6                KING MONADA LIMPOPO      190000  46934084           53
# 7                Romeo ThaGreatwhite       10900    879149           41
# 8                           Makhadzi      263000  88662381           61
# 9                      Xitsonga Misc        2060    439353           42
# 10                        Racha Kill        3360    561979           63
# 11                         Ras Canly        4940    974649           16
# ...

# %%
channel_data["Subscribers"]=pd.to_numeric(channel_data['Subscribers'])
channel_data["Views"]=pd.to_numeric(channel_data['Views'])
channel_data["Total_videos"]=pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# dtype: object

# %%
sns.set(rc={'figure.figsize':(50,50)})
ax=sns.barplot(y="Channel_name",x="Subscribers",data=channel_data)

# %%
sns.set(rc={'figure.figsize':(50,50)})
ax=sns.barplot(x="Channel_name",y="Views",data=channel_data)
